# %%
from IPython.core.display import HTML
HTML("<iframe src=http://pandas.pydata.org width=800 height=350></iframe>")
# Out:
# <iframe src=http://pandas.pydata.org width=800 height=350></iframe>

# %%
import datetime

import pandas as pd
import pandas.io.data
from pandas import Series, DataFrame
pd.__version__
# Out:
# '0.11.0'

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('figure', figsize=(8, 7))
mpl.__version__
# Out:
# '1.2.1'

# %% [markdown]
# Creating/loading time series data
# ===================
#
# * From Python structures
# * From CSV files
# * From Yahoo finance

# %% [markdown]
# ### From Python structures

# %%
labels = ['a', 'b', 'c', 'd', 'e']
s = Series(randn(5), index=labels)
s
# Out:
# a    0.834073
# b   -0.033562
# c   -0.402965
# d    0.929467
# e    1.814118
# dtype: float64

# %%
'b' in s
# Out:
# True

# %%
s['b']
# Out:
# -0.033561757368335082

# %%
mapping = s.to_dict()
mapping
# Out:
# {'a': 0.83407276690033838,
#  'b': -0.033561757368335082,
#  'c': -0.40296469260488499,
#  'd': 0.92946743060787629,
#  'e': 1.8141176278875564}

# %%
Series(mapping)
# Out:
# a    0.834073
# b   -0.033562
# c   -0.402965
# d    0.929467
# e    1.814118
# dtype: float64

# %% [markdown]
# ### From Yahoo finance

# %%
aapl = pd.io.data.get_data_yahoo('AAPL', start=datetime.datetime(2011, 10, 1), end=datetime.datetime(2012, 1, 1))
aapl.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72
# 2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67
# 2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30
# 2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44
# 2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02

# %% [markdown]
# ### From CSV files

# %%
aapl.to_csv('data/aapl_ohlc.csv')
# !head data/aapl_ohlc.csv
# Out:
# Date,Open,High,Low,Close,Volume,Adj Close
# 2011-10-03,380.37,382.64,373.17,374.6,23896400,366.72
# 2011-10-04,374.57,381.8,354.24,372.5,44059900,364.67
# 2011-10-05,367.86,379.82,360.3,378.25,28088200,370.3
# 2011-10-06,373.33,384.78,371.8,377.37,29020800,369.44
# 2011-10-07,375.78,377.74,368.49,369.8,19123500,362.02
# 2011-10-10,379.09,388.81,378.21,388.81,15804100,380.64
# 2011-10-11,392.57,403.18,391.5,400.29,21631700,391.87
# 2011-10-12,407.34,409.25,400.14,402.19,22224500,393.73
# 2011-10-13,404.98,408.43,402.85,408.43,15220900,399.84

# %%
pd.read_csv('data/aapl_ohlc.csv').head()
# Out:
#          Date    Open    High     Low   Close    Volume  Adj Close
# 0  2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72
# 1  2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67
# 2  2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30
# 3  2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44
# 4  2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02

# %% [markdown]
# What happened to our date index?

# %%
df = pd.read_csv('data/aapl_ohlc.csv', index_col='Date')
df.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72
# 2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67
# 2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30
# 2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44
# 2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02

# %%
df.index
# Out:
# Index([2011-10-03, 2011-10-04, 2011-10-05, 2011-10-06, 2011-10-07, 2011-10-10, 2011-10-11, 2011-10-12, 2011-10-13, 2011-10-14, 2011-10-17, 2011-10-18, 2011-10-19, 2011-10-20, 2011-10-21, 2011-10-24, 2011-10-25, 2011-10-26, 2011-10-27, 2011-10-28, 2011-10-31, 2011-11-01, 2011-11-02, 2011-11-03, 2011-11-04, 2011-11-07, 2011-11-08, 2011-11-09, 2011-11-10, 2011-11-11, 2011-11-14, 2011-11-15, 2011-11-16, 2011-11-17, 2011-11-18, 2011-11-21, 2011-11-22, 2011-11-23, 2011-11-25, 2011-11-28, 2011-11-29, 2011-11-30, 2011-12-01, 2011-12-02, 2011-12-05, 2011-12-06, 2011-12-07, 2011-12-08, 2011-12-09, 2011-12-12, 2011-12-13, 2011-12-14, 2011-12-15, 2011-12-16, 2011-12-19, 2011-12-20, 2011-12-21, 2011-12-22, 2011-12-23, 2011-12-27, 2011-12-28, 2011-12-29, 2011-12-30], dtype=object)

# %% [markdown]
# Still no datetimes...

# %%
df = pd.read_csv('data/aapl_ohlc.csv', index_col='Date', parse_dates=True)
df.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close
# Date
# 2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72
# 2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67
# 2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30
# 2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44
# 2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02

# %%
df.index
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2011-10-03 00:00:00, ..., 2011-12-30 00:00:00]
# Length: 63, Freq: None, Timezone: None

# %% [markdown]
# Series and DataFrame: First steps
# =================================
#
# * Indexing
# * Slicing
# * Creating new columns

# %%
ts = df['Close'][-10:]

# %%
ts[:5]
# Out:
# Date
# 2011-12-16    381.02
# 2011-12-19    382.21
# 2011-12-20    395.95
# 2011-12-21    396.45
# 2011-12-22    398.55
# Name: Close, dtype: float64

# %% [markdown]
# A DataFrame is a collection of Series objects. Slicing out a DataFrame column returns a Series.

# %%
type(ts)
# Out:
# pandas.core.series.TimeSeries

# %%
date = ts.index[5]
date
# Out:
# <Timestamp: 2011-12-23 00:00:00>

# %%
ts[date]
# Out:
# 403.32999999999998

# %%
ts[5]
# Out:
# 403.32999999999998

# %% [markdown]
# We can also select multiple columns.

# %%
df[['Open', 'Close']].head()
# Out:
#               Open   Close
# Date
# 2011-10-03  380.37  374.60
# 2011-10-04  374.57  372.50
# 2011-10-05  367.86  378.25
# 2011-10-06  373.33  377.37
# 2011-10-07  375.78  369.80

# %% [markdown]
# New columns can be added on the fly.

# %%
df['diff'] = df.Open - df.Close
df.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close  range   diff
# Date
# 2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72   5.77   5.77
# 2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67   2.07   2.07
# 2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30 -10.39 -10.39
# 2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44  -4.04  -4.04
# 2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02   5.98   5.98

# %%
del df['diff']
df.head()
# Out:
#               Open    High     Low   Close    Volume  Adj Close  range
# Date
# 2011-10-03  380.37  382.64  373.17  374.60  23896400     366.72   5.77
# 2011-10-04  374.57  381.80  354.24  372.50  44059900     364.67   2.07
# 2011-10-05  367.86  379.82  360.30  378.25  28088200     370.30 -10.39
# 2011-10-06  373.33  384.78  371.80  377.37  29020800     369.44  -4.04
# 2011-10-07  375.78  377.74  368.49  369.80  19123500     362.02   5.98

# %% [markdown]
# Data alignment
# ==============
#
# * Join, merge, concatenate
# * Dealing with missing values

# %% [markdown]
# Lets pull some more securities from Yahoo finance and build a DataFrame of the adjusted closing prices.

# %%
series_list = []
securities = ['AAPL', 'GOOG', 'IBM', 'MSFT']
for security in securities:
    s = pd.io.data.get_data_yahoo(security, start=datetime.datetime(2011, 10, 1), end=datetime.datetime(2013, 1, 1))['Adj Close']
    s.name = security # Rename series to match security name
    series_list.append(s)

# %% [markdown]
# `pd.concat` can be used to concatenate multiple `Series` into one `DataFrame`.

# %%
df = pd.concat(series_list, axis=1)
df.head()
# Out:
#               AAPL    GOOG     IBM   MSFT
# Date
# 2011-10-03  366.72  495.52  168.24  23.32
# 2011-10-04  364.67  501.90  169.65  24.09
# 2011-10-05  370.30  504.70  171.69  24.61
# 2011-10-06  369.44  514.71  176.39  25.04
# 2011-10-07  362.02  515.12  177.07  24.95

# %%
df.ix[0, 'AAPL'] = np.nan
df.ix[1, ['GOOG', 'IBM']] = np.nan
df.ix[[1, 2, 3], 'MSFT'] = np.nan

df.head()
# Out:
#               AAPL    GOOG     IBM   MSFT
# Date
# 2011-10-03     NaN  495.52  168.24  23.32
# 2011-10-04  364.67     NaN     NaN    NaN
# 2011-10-05  370.30  504.70  171.69    NaN
# 2011-10-06  369.44  514.71  176.39    NaN
# 2011-10-07  362.02  515.12  177.07  24.95

# %% [markdown]
# Pandas has great support for computing with missing values.

# %%
(df.AAPL + df.GOOG).head()
# Out:
# Date
# 2011-10-03       NaN
# 2011-10-04       NaN
# 2011-10-05    875.00
# 2011-10-06       NaN
# 2011-10-07    877.14
# dtype: float64

# %% [markdown]
# One common approacht to impute missing values in time series is forward filling.

# %%
df.ffill().head()
# Out:
#               AAPL    GOOG     IBM   MSFT
# Date
# 2011-10-03     NaN  495.52  168.24  23.32
# 2011-10-04  364.67  495.52  168.24  23.32
# 2011-10-05  370.30  504.70  171.69  23.32
# 2011-10-06  369.44  514.71  176.39  23.32
# 2011-10-07  362.02  515.12  177.07  24.95

# %% [markdown]
# Plotting Basics
# ---------------

# %%
# Set some Pandas options
pd.set_option('display.notebook_repr_html', False)
pd.set_option('display.max_columns', 20)
pd.set_option('display.max_rows', 25)

# %%
df = pd.io.data.get_data_yahoo(['AA', 'AAPL', 'GE', 'GOOG', 'IBM', 'JNJ', 'KO', 'MSFT', 'PEP', 'XOM'], start=datetime.datetime(2010, 1, 1), end=datetime.datetime(2013, 1, 1))['Adj Close']

# %%
mavg = pd.rolling_mean(df, 10)

# %%
df.plot(subplots=True, figsize=(10, 20));
mavg.plot(subplots=True, figsize=(10, 20));

# %% [markdown]
# Common Financial Computations
# -----------------------------
#
# * Returns
# * Cumulative returns
# * Moving averages
# * Sharpe Ratio

# %% [markdown]
# Returns defined as:
# $$ $$
# $$r_t = \frac{p_t}{p_{t-1}} - 1$$

# %%
rets = df / df.shift(1) - 1
rets.head()
# Out:
#                   AA      AAPL        GE      GOOG       IBM       JNJ  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05 -0.031192  0.001718  0.005069 -0.004404 -0.012121 -0.011530
# 2010-01-06  0.052157 -0.015915 -0.005043 -0.025209 -0.006500  0.008130
# 2010-01-07 -0.021420 -0.001840  0.052136 -0.023280 -0.003435 -0.007188
# 2010-01-08  0.025016  0.006646  0.021335  0.013331  0.010012  0.003355
#
#                   KO      MSFT       PEP       XOM
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05 -0.012029  0.000353  0.012164  0.003949
# 2010-01-06 -0.000393 -0.006360 -0.010045  0.008497
# 2010-01-07 -0.002358 -0.010313 -0.006342 -0.003121
# 2010-01-08 -0.018511  0.006827 -0.003282 -0.003913

# %% [markdown]
# Or alternatively `pct_change()`.

# %%
df.pct_change().head()
# Out:
#                   AA      AAPL        GE      GOOG       IBM       JNJ  \
# Date
# 2010-01-04       NaN       NaN       NaN       NaN       NaN       NaN
# 2010-01-05 -0.031192  0.001718  0.005069 -0.004404 -0.012121 -0.011530
# 2010-01-06  0.052157 -0.015915 -0.005043 -0.025209 -0.006500  0.008130
# 2010-01-07 -0.021420 -0.001840  0.052136 -0.023280 -0.003435 -0.007188
# 2010-01-08  0.025016  0.006646  0.021335  0.013331  0.010012  0.003355
#
#                   KO      MSFT       PEP       XOM
# Date
# 2010-01-04       NaN       NaN       NaN       NaN
# 2010-01-05 -0.012029  0.000353  0.012164  0.003949
# 2010-01-06 -0.000393 -0.006360 -0.010045  0.008497
# 2010-01-07 -0.002358 -0.010313 -0.006342 -0.003121
# 2010-01-08 -0.018511  0.006827 -0.003282 -0.003913

# %%
rets.hist(bins=50);

# %%
plt.scatter(rets.IBM, rets.MSFT)

# %%
pd.scatter_matrix(rets, diagonal='kde', figsize=(20, 20));

# %%
corr = rets.corr()
corr
# Out:
#             AA      AAPL        GE      GOOG       IBM       JNJ        KO  \
# AA    1.000000  0.478876  0.675135  0.500074  0.572698  0.564784  0.507531
# AAPL  0.478876  1.000000  0.457186  0.533405  0.501582  0.396521  0.388537
# GE    0.675135  0.457186  1.000000  0.462540  0.609544  0.609929  0.593366
# GOOG  0.500074  0.533405  0.462540  1.000000  0.470798  0.403695  0.404247
# IBM   0.572698  0.501582  0.609544  0.470798  1.000000  0.559202  0.602032
# JNJ   0.564784  0.396521  0.609929  0.403695  0.559202  1.000000  0.597509
# KO    0.507531  0.388537  0.593366  0.404247  0.602032  0.597509  1.000000
# MSFT  0.578826  0.472015  0.600145  0.472152  0.645565  0.537362  0.523689
# PEP   0.427073  0.309023  0.532517  0.329978  0.490668  0.547643  0.636500
# XOM   0.697509  0.449371  0.708806  0.510788  0.636322  0.666701  0.659331
#
#           MSFT       PEP       XOM
# AA    0.578826  0.427073  0.697509
# AAPL  0.472015  0.309023  0.449371
# GE    0.600145  0.532517  0.708806
# GOOG  0.472152  0.329978  0.510788
# IBM   0.645565  0.490668  0.636322
# JNJ   0.537362  0.547643  0.666701
# KO    0.523689  0.636500  0.659331
# MSFT  1.000000  0.476464  0.631850
# PEP   0.476464  1.000000  0.549259
# XOM   0.631850  0.549259  1.000000

# %%
plt.imshow(corr, cmap='hot', interpolation='none')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns)
plt.yticks(range(len(corr)), corr.columns);

# %% [markdown]
# One thing we are often interested in is the relationship of expected returns and the risk we are taking one. Often there is a trade-off between the two.
#
# Here we use `plt.annotate` to put labels on the scatterplot.

# %%
plt.scatter(rets.mean(), rets.std())
plt.xlabel('Expected returns')
plt.ylabel('Risk')
for label, x, y in zip(rets.columns, rets.mean(), rets.std()):
    plt.annotate(
        label, 
        xy = (x, y), xytext = (20, -20),
        textcoords = 'offset points', ha = 'right', va = 'bottom',
        bbox = dict(boxstyle = 'round,pad=0.5', fc = 'yellow', alpha = 0.5),
        arrowprops = dict(arrowstyle = '->', connectionstyle = 'arc3,rad=0'))

# %% [markdown]
# Works on DataFrame too
# ----------------------

# %%
last_30days = close_px.ix[-30:, ['AAPL', 'MSFT', 'IBM']]
last_30days
# Out:
#             AAPL   MSFT   IBM
# 2011-09-02  374.1  25.8   167
# 2011-09-06  379.7  25.51  165.1
# 2011-09-07  383.9  26     167.3
# 2011-09-08  384.1  26.22  165.2
# 2011-09-09  377.5  25.74  161.4
# 2011-09-12  379.9  25.89  162.4
# 2011-09-13  384.6  26.04  163.4
# 2011-09-14  389.3  26.5   167.2
# 2011-09-15  393    26.99  170.1
# 2011-09-16  400.5  27.12  173
# 2011-09-19  411.6  27.21  173.1
# 2011-09-20  413.4  26.98  174.7
# 2011-09-21  412.1  25.99  173
# 2011-09-22  401.8  25.06  168.6
# 2011-09-23  404.3  25.06  169.3
# 2011-09-26  403.2  25.44  174.5
# 2011-09-27  399.3  25.67  177.7
# 2011-09-28  397    25.58  177.6
# 2011-09-29  390.6  25.45  179.2
# 2011-09-30  381.3  24.89  174.9
# 2011-10-03  374.6  24.53  173.3
# 2011-10-04  372.5  25.34  174.7
# 2011-10-05  378.2  25.89  176.8
# 2011-10-06  377.4  26.34  181.7
# 2011-10-07  369.8  26.25  182.4
# 2011-10-10  388.8  26.94  186.6
# 2011-10-11  400.3  27     185
# 2011-10-12  402.2  26.96  186.1
# 2011-10-13  408.4  27.18  186.8
# 2011-10-14  422    27.27  190.5

# %%
last_30days[::5]
# Out:
#             AAPL   MSFT   IBM
# 2011-09-02  374.1  25.8   167
# 2011-09-12  379.9  25.89  162.4
# 2011-09-19  411.6  27.21  173.1
# 2011-09-26  403.2  25.44  174.5
# 2011-10-03  374.6  24.53  173.3
# 2011-10-10  388.8  26.94  186.6

# %%
last_30days[::5].reindex(last_30days.index, method='ffill')
# Out:
#             AAPL   MSFT   IBM
# 2011-09-02  374.1  25.8   167
# 2011-09-06  374.1  25.8   167
# 2011-09-07  374.1  25.8   167
# 2011-09-08  374.1  25.8   167
# 2011-09-09  374.1  25.8   167
# 2011-09-12  379.9  25.89  162.4
# 2011-09-13  379.9  25.89  162.4
# 2011-09-14  379.9  25.89  162.4
# 2011-09-15  379.9  25.89  162.4
# 2011-09-16  379.9  25.89  162.4
# 2011-09-19  411.6  27.21  173.1
# 2011-09-20  411.6  27.21  173.1
# 2011-09-21  411.6  27.21  173.1
# 2011-09-22  411.6  27.21  173.1
# 2011-09-23  411.6  27.21  173.1
# 2011-09-26  403.2  25.44  174.5
# 2011-09-27  403.2  25.44  174.5
# 2011-09-28  403.2  25.44  174.5
# 2011-09-29  403.2  25.44  174.5
# 2011-09-30  403.2  25.44  174.5
# 2011-10-03  374.6  24.53  173.3
# 2011-10-04  374.6  24.53  173.3
# 2011-10-05  374.6  24.53  173.3
# 2011-10-06  374.6  24.53  173.3
# 2011-10-07  374.6  24.53  173.3
# 2011-10-10  388.8  26.94  186.6
# 2011-10-11  388.8  26.94  186.6
# 2011-10-12  388.8  26.94  186.6
# 2011-10-13  388.8  26.94  186.6
# 2011-10-14  388.8  26.94  186.6

# %%
close_px / close_px.shift(1) - 1
# Out:
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# Index: 5472 entries, 1990-02-01 00:00:00 to 2011-10-14 00:00:00
# Data columns:
# AA      5471  non-null values
# AAPL    5471  non-null values
# GE      5471  non-null values
# IBM     5471  non-null values
# JNJ     5471  non-null values
# MSFT    5471  non-null values
# PEP     5469  non-null values
# SPX     5471  non-null values
# XOM     5471  non-null values
# dtypes: float64(9)

# %%
rets = close_px / close_px.shift(1) - 1

# %% [markdown]
# Form return index
#
# $ $
#
# $$i_t = (1 + r_t) \cdot i_{t-1}, \quad i_0 = 1$$

# %%
daily_index = (1 + rets).cumprod()
daily_index['IBM'].plot()

# %%
monthly_index = daily_index.asfreq('EOM')
monthly_index[:30]

#oops, careful about those NAs!
monthly_index = daily_index.asfreq('EOM', method='ffill')
monthly_index[:30]
# Out:
#             AA      AAPL    GE      IBM     JNJ     MSFT    PEP     SPX     XOM
# 1990-02-28  1.047   1.011   1       1.063   1.005   1.053   1.004   1.009   1
# 1990-03-30  1.055   1.197   1.04    1.086   1.052   1.181   1.075   1.034   0.984
# 1990-04-30  1.01    1.171   1.036   1.115   1.061   0.6187  1.137   1.006   0.9628
# 1990-05-31  1.075   1.227   1.115   1.228   1.197   0.7787  1.268   1.099   1.021
# 1990-06-29  1.039   1.331   1.121   1.202   1.269   0.8107  1.333   1.089   1.019
# 1990-07-31  1.132   1.249   1.16    1.141   1.323   0.7093  1.322   1.083   1.104
# 1990-08-31  1.049   1.1     1.004   1.042   1.229   0.656   1.29    0.9811  1.064
# 1990-09-28  1.02    0.8623  0.8826  1.088   1.185   0.672   0.3948  0.9308  1.043
# 1990-10-31  0.8656  0.9144  0.8421  1.079   1.206   0.68    0.412   0.9246  1.043
# 1990-11-30  0.8941  1.093   0.8866  1.162   1.307   0.7707  0.4398  0.98    1.077
# 1990-12-31  0.9389  1.279   0.9292  1.156   1.344   0.8027  0.4464  1.004   1.101
# 1991-01-31  1.049   1.65    1.036   1.297   1.433   1.047   0.4721  1.046   1.099
# 1991-02-28  1.045   1.702   1.101   1.317   1.538   1.107   0.5622  1.116   1.173
# 1991-03-29  1.067   2.022   1.127   1.165   1.796   1.132   0.588   1.141   1.245
# 1991-04-30  1.1     1.635   1.146   1.054   1.77    1.056   0.5473  1.142   1.266
# 1991-05-31  1.159   1.398   1.251   1.086   1.698   1.171   0.5387  1.186   1.239
# 1991-06-28  1.1     1.234   1.198   0.9936  1.564   0.7266  0.4979  1.129   1.237
# 1991-07-31  1.151   1.375   1.186   1.036   1.716   0.784   0.5473  1.18    1.263
# 1991-08-30  1.128   1.576   1.212   0.991   1.74    0.9093  0.5559  1.203   1.239
# 1991-09-30  1.041   1.472   1.123   1.06    1.655   0.9493  0.4893  1.18    1.266
# 1991-10-31  1.033   1.531   1.117   1.005   1.782   1.001   0.4893  1.194   1.298
# 1991-11-29  0.9531  1.509   1.049   0.9463  1.805   1.037   0.5085  1.141   1.247
# 1991-12-31  1.049   1.676   1.239   0.9105  2.145   1.187   0.5816  1.269   1.295
# 1992-01-31  1.051   1.925   1.219   0.9207  2.014   1.283   0.5794  1.243   1.239
# 1992-02-28  1.13    2.007   1.273   0.8887  1.897   1.317   0.5536  1.255   1.216
# 1992-03-31  1.149   1.732   1.227   0.8542  1.827   1.264   0.588   1.228   1.165
# 1992-04-30  1.261   1.788   1.241   0.9284  1.777   1.176   0.6266  1.262   1.277
# 1992-05-29  1.265   1.777   1.237   0.9284  1.815   1.291   0.6266  1.263   1.29
# 1992-06-30  1.236   1.427   1.259   1.001   0.8383  0.7467  0.5988  1.241   1.317
# 1992-07-31  1.202   1.39    1.239   0.9693  0.9226  0.776   0.6417  1.29    1.351

# %%
monthly_rets = monthly_index / monthly_index.shift(1) - 1

# %% [markdown]
# Multiple time series manipulation
# =================================

# %%
df2 = df.copy()

# set some NAs
df2.ix[[0, 7], 'AAPL'] = np.nan
df2.ix[[2, 4], 'IBM'] = np.nan
df2
# Out:
#             AAPL   IBM    MSFT
# 2011-10-03  NaN    173.3  24.53
# 2011-10-04  372.5  174.7  25.34
# 2011-10-05  378.2  NaN    25.89
# 2011-10-06  377.4  181.7  26.34
# 2011-10-07  369.8  NaN    26.25
# 2011-10-10  388.8  186.6  26.94
# 2011-10-11  400.3  185    27
# 2011-10-12  NaN    186.1  26.96
# 2011-10-13  408.4  186.8  27.18
# 2011-10-14  422    190.5  27.27

# %%
df2.fillna(method='ffill')
# Out:
#             AAPL   IBM    MSFT
# 2011-10-03  NaN    173.3  24.53
# 2011-10-04  372.5  174.7  25.34
# 2011-10-05  378.2  174.7  25.89
# 2011-10-06  377.4  181.7  26.34
# 2011-10-07  369.8  181.7  26.25
# 2011-10-10  388.8  186.6  26.94
# 2011-10-11  400.3  185    27
# 2011-10-12  400.3  186.1  26.96
# 2011-10-13  408.4  186.8  27.18
# 2011-10-14  422    190.5  27.27

# %%
df['AAPL'].mean()
# Out:
# 389.42399999999998

# %% [markdown]
# Basic statistics like count, sum, mean, std,

# %%
df2.mean(0)
# Out:
# AAPL    389.68125
# IBM     183.10125
# MSFT    26.37
# Name: None, Length: 3

# %%
weights = Series(rand(3), index=df2.columns)
weights /= weights.sum()
df2
# Out:
#             AAPL   IBM    MSFT
# 2011-10-03  NaN    173.3  24.53
# 2011-10-04  372.5  174.7  25.34
# 2011-10-05  378.2  NaN    25.89
# 2011-10-06  377.4  181.7  26.34
# 2011-10-07  369.8  NaN    26.25
# 2011-10-10  388.8  186.6  26.94
# 2011-10-11  400.3  185    27
# 2011-10-12  NaN    186.1  26.96
# 2011-10-13  408.4  186.8  27.18
# 2011-10-14  422    190.5  27.27

# %% [markdown]
# Subtracting a Series matches on the column names

# %%
df2 - df2.ix[3]
# Out:
#             AAPL   IBM   MSFT
# 2011-10-03  NaN   -8.4  -1.81
# 2011-10-04 -4.87  -6.95 -1
# 2011-10-05  0.88   NaN  -0.45
# 2011-10-06  0      0     0
# 2011-10-07 -7.57   NaN  -0.09
# 2011-10-10  11.44  4.93  0.6
# 2011-10-11  22.92  3.31  0.66
# 2011-10-12  NaN    4.43  0.62
# 2011-10-13  31.06  5.13  0.84
# 2011-10-14  44.63  8.84  0.93

# %%
df2 - df2.mean(0)

# %%
(df2.T - df2.mean(1)).T
# Out:
#             AAPL   IBM    MSFT
# 2011-10-03  NaN    74.38 -74.38
# 2011-10-04  181.6 -16.12 -165.5
# 2011-10-05  176.2  NaN   -176.2
# 2011-10-06  182.2 -13.44 -168.8
# 2011-10-07  171.8  NaN   -171.8
# 2011-10-10  188   -14.17 -173.9
# 2011-10-11  196.2 -19.1  -177.1
# 2011-10-12  NaN    79.58 -79.58
# 2011-10-13  201   -20.66 -180.3
# 2011-10-14  208.7 -22.74 -186

# %% [markdown]
# Except in the special case where you subtract a **TimeSeries** from a **DataFrame** with a datetime index

# %%
# standardize cross-sectionally
std_xs = (df2 - df2.mean(1)) / df2.std(1)
std_xs.mean(1)
# Out:
# 2011-10-03    0.0
# 2011-10-04    -3.70074341542e-17
# 2011-10-05    0.0
# 2011-10-06    3.70074341542e-17
# 2011-10-07    0.0
# 2011-10-10    -2.59052039079e-16
# 2011-10-11    7.40148683083e-17
# 2011-10-12    -1.11022302463e-16
# 2011-10-13    0.0
# 2011-10-14    1.11022302463e-16
# Name: None, Length: 10

# %%
std_xs.count()
# Out:
# AAPL    8
# IBM     8
# MSFT    10
# Name: None, Length: 3

# %% [markdown]
# Plotting
# ========
#
# Some basic plotting integration with matplotlib in Series / DataFrame

# %%
subrets = rets.ix[:, ['AAPL', 'IBM', 'XOM', 'MSFT']]
subrets
# Out:
# &lt;class &apos;pandas.core.frame.DataFrame&apos;&gt;
# Index: 5472 entries, 1990-02-01 00:00:00 to 2011-10-14 00:00:00
# Data columns:
# AAPL    5471  non-null values
# IBM     5471  non-null values
# XOM     5471  non-null values
# MSFT    5471  non-null values
# dtypes: float64(4)

# %%
(1 + subrets).cumprod().plot()
legend(loc='best')
title('Cumulative value of $1 invested')
# Out:
# &lt;matplotlib.text.Text at 0x10ca999d0&gt;

# %%
#subrets.hist(bins=50)
rets[-250:].hist(bins=50)

# %%
rets.ix[-1]
# Out:
# AA      0.0158415841584
# AAPL    0.0332247876013
# GE      0.0234278668311
# IBM     0.0198586875067
# JNJ     0.00762883387825
# MSFT    0.00331125827815
# PEP     -0.00192431045542
# SPX     0.0173803233471
# XOM     0.0227838156344
# Name: 2011-10-14 00:00:00, Length: 9

# %%
rets.ix[-1].plot(kind='bar')
title('Returns on %s' % rets.index[-1])
axhline(0)
# Out:
# &lt;matplotlib.lines.Line2D at 0x10cdde350&gt;

# %% [markdown]
# Moving window functions
# =======================

# %%
px = close_px['AAPL']
px.plot()

# %%
px.plot()
rolling_mean(px, 60, min_periods=50).plot()
plt.xlim([datetime(2004, 1, 1), datetime(2006, 1, 1)])
plt.ylim([0, 100])
# Out:
# (0, 100)

# %% [markdown]
# Time rule shortcuts
# -------------------
#
# These aliases are provided as a pure convenience
#
# <table>
#     <tr><td>Name</td><td>Description</td></tr>
#     <tr><td>WEEKDAY</td><td>Business day</td></tr>
#     <tr><td>EOM</td><td>Business end of month</td></tr>
#     <tr><td>W@MON</td><td>Weekly on Monday</td></tr>
#     <tr><td>W@TUE</td><td>Weekly on Tuesday</td></tr>
#     <tr><td>W@WED</td><td>Weekly on Wednesday</td></tr>
#     <tr><td>W@THU</td><td>Weekly on Thursday</td></tr>
#     <tr><td>W@FRI</td><td>Weekly on Friday</td></tr>
#     <tr><td>Q@MAR</td><td>Quarterly (anchored at March)</td></tr>
#     <tr><td>A@DEC</td><td>Business year end (December)</td></tr>
# </table>

# %% [markdown]
# Frequency conversions
# ---------------------

# %%
close_px.asfreq(datetools.BMonthEnd()
             )[:20]
# Out:
#             AA    AAPL   GE    IBM    JNJ   MSFT  PEP    SPX    XOM
# 1990-02-28  5.22  7.97   2.89  18.06  4.32  0.54  6.06   331.9  6.2
# 1990-03-30  5.26  9.43   3.01  18.45  4.52  0.6   6.52   339.9  6.1
# 1990-04-30  5.07  9.23   2.99  18.95  4.56  0.63  6.9    330.8  5.97
# 1990-05-31  5.39  9.69   3.24  21.1   5.17  0.8   7.69   361.2  6.42
# 1990-06-29  5.21  10.52  3.26  20.66  5.48  0.83  8.11   358    6.4
# 1990-07-31  5.74  9.87   3.37  19.6   5.71  0.73  8.05   356.1  6.93
# 1990-08-31  5.32  8.72   2.92  18.11  5.34  0.67  7.85   322.6  6.76
# 1990-09-28  5.18  6.83   2.59  18.91  5.14  0.69  7.24   306.1  6.62
# 1990-10-31  4.42  7.25   2.47  18.76  5.24  0.7   7.55   304    6.62
# 1990-11-30  4.57  8.69   2.6   20.43  5.7   0.79  8.07   322.2  6.94
# 1990-12-31  4.8   10.17  2.75  20.32  5.87  0.82  8.21   330.2  7.09
# 1991-01-31  5.41  13.12  3.07  22.79  6.25  1.07  8.69   343.9  7.07
# 1991-02-28  5.39  13.57  3.28  23.37  6.74  1.13  10.35  367.1  7.65
# 1991-03-29  NaN   NaN    NaN   NaN    NaN   NaN   NaN    NaN    NaN
# 1991-04-30  5.71  13.03  3.42  18.7   7.76  1.08  10.1   375.3  8.26
# 1991-05-31  6.02  11.17  3.76  19.49  7.47  1.2   9.94   389.8  8.18
# 1991-06-28  5.71  9.86   3.6   17.84  6.89  1.12  9.23   371.2  8.16
# 1991-07-31  6.01  10.99  3.56  18.6   7.55  1.2   10.14  387.8  8.34
# 1991-08-30  5.89  12.62  3.64  18.01  7.69  1.4   10.3   395.4  8.27
# 1991-09-30  5.44  11.79  3.4   19.26  7.32  1.46  9.1    387.9  8.45

# %%
# same thing as
rng = DateRange(close_px.index[0], close_px.index[-1],
                time_rule='EOM')
close_px.reindex(rng)[:20]

# %% [markdown]
# GroupBy
# =======

# %%
df = DataFrame({'A' : ['foo', 'bar', 'foo', 'bar',
                       'foo', 'bar', 'foo', 'foo'],
                'B' : ['one', 'one', 'two', 'three',
                       'two', 'two', 'one', 'three'],
                'C' : np.random.randn(8),
                'D' : np.random.randn(8)})
df
# Out:
#    A    B      C       D
# 0  foo  one   -0.8596 -0.9065
# 1  bar  one   -0.4241 -1.505
# 2  foo  two   -0.7761  1.392
# 3  bar  three  1.279  -0.02779
# 4  foo  two    0.9438 -0.631
# 5  bar  two   -1.002  -0.6624
# 6  foo  one    0.3065  2.725
# 7  foo  three  0.3075 -1.847

# %%
for key, group in df.groupby('A'):
    print key
    print group
# Out:
# bar
#    A    B      C       D
# 1  bar  one   -0.4241 -1.505
# 3  bar  three  1.279  -0.02779
# 5  bar  two   -1.002  -0.6624
#
# foo
#    A    B      C       D
# 0  foo  one   -0.8596 -0.9065
# 2  foo  two   -0.7761  1.392
# 4  foo  two    0.9438 -0.631
# 6  foo  one    0.3065  2.725
# 7  foo  three  0.3075 -1.847

# %%
df.groupby('A')['C'].describe().T
# Out:
#        bar      foo
# count  3        5
# mean  -0.04889 -0.01559
# std    1.186    0.7777
# min   -1.002   -0.8596
# 25%   -0.713   -0.7761
# 50%   -0.4241   0.3065
# 75%    0.4276   0.3075
# max    1.279    0.9438

# %%
df.groupby('A').mean()
# Out:
#      C        D
# bar -0.04889 -0.7318
# foo -0.01559  0.1465

# %%
for key, group in df.groupby('A'):
    print key
    print group

# %%
df.groupby(['A', 'B']).mean()

# %%
df.groupby(['A', 'B'], as_index=False).mean()

# %%
grouped = rets.groupby(lambda x: x.year)
for year, group in grouped:
    print year
    print group[:5]
